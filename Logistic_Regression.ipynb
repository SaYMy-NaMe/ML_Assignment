# %% [markdown]
# <a href="https://colab.research.google.com/github/SaYMy-NaMe/ML_Assignment/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree

# %% [markdown]
# Generate synthetic dataset

# %%
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# %% [markdown]
# Train Logistic Regression model

# %%
logistic_regression_model = LogisticRegression()
logistic_regression_model.fit(X, y)
# Out:
# LogisticRegression()

# %% [markdown]
# Train Decision Tree model

# %%
decision_tree_model = DecisionTreeClassifier()
decision_tree_model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Plot Logistic Regression Decision Boundary

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu)
plt.title('Logistic Regression Decision Boundary')

xx, yy = np.meshgrid(np.linspace(X[:, 0].min(), X[:, 0].max(), 100),
                     np.linspace(X[:, 1].min(), X[:, 1].max(), 100))
Z = logistic_regression_model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.RdYlBu)

# %% [markdown]
# Plot Decision Tree

# %%
plt.subplot(1, 2, 2)
plot_tree(decision_tree_model, filled=True, feature_names=['Feature 1', 'Feature 2'], class_names=['Class 0', 'Class 1'])
plt.title('Decision Tree')
# Out:
# Text(0.5, 1.0, 'Decision Tree')

# %% [markdown]
# Show the plots

# %%
plt.show()
